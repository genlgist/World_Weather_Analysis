# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cf7a33ed04b474ee0d19ed1cace7bd5c

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 1 | mago
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | lorengau
# Processing Record 5 of Set 1 | norman wells
# Processing Record 6 of Set 1 | bonga
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | uruzgan
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | eyrarbakki
# Processing Record 13 of Set 1 | kamskiye polyany
# Processing Record 14 of Set 1 | hammerfest
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | north augusta
# Processing Record 17 of Set 1 | nouadhibou
# Processing Record 18 of Set 1 | katsuura
# Processing Record 19 of Set 1 | nanortalik
# Processing Record 20 of Set 1 | parrita
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | morshansk
# Processing Record 23 of Set 1 | sambava
# Processing Record 24 of Set 1 | fallon
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | kyra
# Processing Record 27 of Set 1 | burnie
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | san quintin
# Processing Record 31 of Set 1 | anadyr
# Processing Record 32 of Set 1 | shetpe
# Processing Record 33 of Set 1 | muromtsevo
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | bathsheba
# Processing Record 36 of Set 1 | luanda
# Processing Record 37 of Set 1 | port moresby
# Processing Record 38 of Set 1 | port lincoln
# Processing Record 39 of Set 1 | severo-kurilsk
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | broome
# Processing Record 43 of Set 1 | artesia
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | vega de alatorre
# Processing Record 47 of Set 1 | mokrousovo
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 1 | waipawa
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 1 of Set 2 | concordia
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | pisco
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | bengkulu
# Processing Record 7 of Set 2 | sanand
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | homer
# Processing Record 10 of Set 2 | porto novo
# Processing Record 11 of Set 2 | college
# Processing Record 12 of Set 2 | ilulissat
# Processing Record 13 of Set 2 | puno
# Processing Record 14 of Set 2 | kaifeng
# Processing Record 15 of Set 2 | ust-ilimsk
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | saint george
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | hovd
# Processing Record 20 of Set 2 | lebu
# Processing Record 21 of Set 2 | verkhoyansk
# Processing Record 22 of Set 2 | tunxi
# City not found. Skipping...
# Processing Record 23 of Set 2 | pacific grove
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | ekibastuz
# Processing Record 26 of Set 2 | lasem
# Processing Record 27 of Set 2 | presidencia roque saenz pena
# Processing Record 28 of Set 2 | metlika
# Processing Record 29 of Set 2 | cabedelo
# Processing Record 30 of Set 2 | baoma
# Processing Record 31 of Set 2 | tikamgarh
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | karratha
# Processing Record 34 of Set 2 | languyan
# Processing Record 35 of Set 2 | nome
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | savannah bight
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | chokurdakh
# Processing Record 40 of Set 2 | sinnamary
# Processing Record 41 of Set 2 | atar
# Processing Record 42 of Set 2 | boa vista
# Processing Record 43 of Set 2 | payson
# Processing Record 44 of Set 2 | gallup
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | harper
# Processing Record 47 of Set 2 | klaksvik
# Processing Record 48 of Set 2 | hay river
# Processing Record 49 of Set 2 | juneau
# Processing Record 50 of Set 2 | belmonte
# Processing Record 1 of Set 3 | aripuana
# Processing Record 2 of Set 3 | okato
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 6 of Set 3 | mar del plata
# Processing Record 7 of Set 3 | namibe
# Processing Record 8 of Set 3 | samana
# Processing Record 9 of Set 3 | broken hill
# Processing Record 10 of Set 3 | alofi
# Processing Record 11 of Set 3 | the valley
# Processing Record 12 of Set 3 | qaqortoq
# Processing Record 13 of Set 3 | saldanha
# Processing Record 14 of Set 3 | atasu
# Processing Record 15 of Set 3 | bangangte
# Processing Record 16 of Set 3 | fairbanks
# Processing Record 17 of Set 3 | takoradi
# Processing Record 18 of Set 3 | bairiki
# Processing Record 19 of Set 3 | madimba
# Processing Record 20 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | ortigueira
# Processing Record 22 of Set 3 | xadani
# City not found. Skipping...
# Processing Record 23 of Set 3 | barrow
# Processing Record 24 of Set 3 | perth
# Processing Record 25 of Set 3 | yaan
# Processing Record 26 of Set 3 | qaanaaq
# Processing Record 27 of Set 3 | kapaa
# Processing Record 28 of Set 3 | athabasca
# Processing Record 29 of Set 3 | cockburn town
# Processing Record 30 of Set 3 | cairns
# Processing Record 31 of Set 3 | kyshtovka
# Processing Record 32 of Set 3 | biak
# Processing Record 33 of Set 3 | comodoro rivadavia
# Processing Record 34 of Set 3 | diego de almagro
# Processing Record 35 of Set 3 | konstantinovka
# Processing Record 36 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 3 | seoul
# Processing Record 38 of Set 3 | iqaluit
# Processing Record 39 of Set 3 | zhigansk
# Processing Record 40 of Set 3 | cuicatlan
# Processing Record 41 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 3 | san patricio
# Processing Record 43 of Set 3 | constitucion
# Processing Record 44 of Set 3 | tiznit
# Processing Record 45 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 3 | carnarvon
# Processing Record 47 of Set 3 | chuy
# Processing Record 48 of Set 3 | davila
# Processing Record 49 of Set 3 | tessalit
# Processing Record 50 of Set 3 | garissa
# Processing Record 1 of Set 4 | krasnoborsk
# Processing Record 2 of Set 4 | khatanga
# Processing Record 3 of Set 4 | puerto del rosario
# Processing Record 4 of Set 4 | nishihara
# Processing Record 5 of Set 4 | padang
# Processing Record 6 of Set 4 | ixtapa
# Processing Record 7 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 4 | wloszczowa
# Processing Record 9 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 4 | kaeo
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | gaoyou
# Processing Record 13 of Set 4 | pemba
# Processing Record 14 of Set 4 | ginda
# Processing Record 15 of Set 4 | belaya gora
# Processing Record 16 of Set 4 | gola gokarannath
# Processing Record 17 of Set 4 | ballina
# Processing Record 18 of Set 4 | paamiut
# Processing Record 19 of Set 4 | cape town
# Processing Record 20 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 4 | jalu
# Processing Record 22 of Set 4 | erzin
# Processing Record 23 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 4 | upernavik
# Processing Record 25 of Set 4 | bundaberg
# Processing Record 26 of Set 4 | kavaratti
# Processing Record 27 of Set 4 | gimli
# Processing Record 28 of Set 4 | maloshuyka
# City not found. Skipping...
# Processing Record 29 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 4 | mayo
# Processing Record 31 of Set 4 | vreed en hoop
# City not found. Skipping...
# Processing Record 32 of Set 4 | inirida
# Processing Record 33 of Set 4 | whitianga
# Processing Record 34 of Set 4 | caceres
# Processing Record 35 of Set 4 | provideniya
# Processing Record 36 of Set 4 | jamestown
# Processing Record 37 of Set 4 | bubaque
# Processing Record 38 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 4 | longyearbyen
# Processing Record 40 of Set 4 | mokhsogollokh
# Processing Record 41 of Set 4 | thabazimbi
# Processing Record 42 of Set 4 | faya
# Processing Record 43 of Set 4 | udachnyy
# Processing Record 44 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 4 | kamenka
# Processing Record 46 of Set 4 | masvingo
# Processing Record 47 of Set 4 | san cristobal
# Processing Record 48 of Set 4 | poum
# Processing Record 49 of Set 4 | oxford
# Processing Record 50 of Set 4 | arraial do cabo
# Processing Record 1 of Set 5 | svetlogorsk
# Processing Record 2 of Set 5 | okhotsk
# Processing Record 3 of Set 5 | arman
# Processing Record 4 of Set 5 | turukhansk
# Processing Record 5 of Set 5 | ust-karsk
# Processing Record 6 of Set 5 | srandakan
# Processing Record 7 of Set 5 | itarema
# Processing Record 8 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 5 | inta
# Processing Record 10 of Set 5 | jiuquan
# Processing Record 11 of Set 5 | bethel
# Processing Record 12 of Set 5 | salisbury
# Processing Record 13 of Set 5 | palmer
# Processing Record 14 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 15 of Set 5 | liepaja
# Processing Record 16 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 17 of Set 5 | atuona
# Processing Record 18 of Set 5 | dikson
# Processing Record 19 of Set 5 | kruisfontein
# Processing Record 20 of Set 5 | okulovka
# Processing Record 21 of Set 5 | sterling
# Processing Record 22 of Set 5 | grand gaube
# Processing Record 23 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 24 of Set 5 | lagoa
# Processing Record 25 of Set 5 | fortuna
# Processing Record 26 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 27 of Set 5 | mount gambier
# Processing Record 28 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 5 | vardo
# Processing Record 31 of Set 5 | kapurthala
# Processing Record 32 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 5 | sabalgarh
# Processing Record 34 of Set 5 | asyut
# Processing Record 35 of Set 5 | hervey bay
# Processing Record 36 of Set 5 | santa isabel do rio negro
# Processing Record 37 of Set 5 | meulaboh
# Processing Record 38 of Set 5 | andrelandia
# Processing Record 39 of Set 5 | vao
# Processing Record 40 of Set 5 | cabo san lucas
# Processing Record 41 of Set 5 | yumen
# Processing Record 42 of Set 5 | arcachon
# Processing Record 43 of Set 5 | faanui
# Processing Record 44 of Set 5 | butaritari
# Processing Record 45 of Set 5 | riyadh
# Processing Record 46 of Set 5 | hobyo
# Processing Record 47 of Set 5 | udarnyy
# Processing Record 48 of Set 5 | galveston
# Processing Record 49 of Set 5 | talnakh
# Processing Record 50 of Set 5 | puerto colombia
# Processing Record 1 of Set 6 | la union
# Processing Record 2 of Set 6 | coquimbo
# Processing Record 3 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 6 | avera
# Processing Record 5 of Set 6 | mount isa
# Processing Record 6 of Set 6 | florida
# Processing Record 7 of Set 6 | mahebourg
# Processing Record 8 of Set 6 | eyl
# Processing Record 9 of Set 6 | darnah
# Processing Record 10 of Set 6 | maningrida
# Processing Record 11 of Set 6 | souillac
# Processing Record 12 of Set 6 | korla
# Processing Record 13 of Set 6 | erenhot
# Processing Record 14 of Set 6 | tecoanapa
# Processing Record 15 of Set 6 | fuerte olimpo
# Processing Record 16 of Set 6 | atherton
# Processing Record 17 of Set 6 | leningradskiy
# Processing Record 18 of Set 6 | agadez
# Processing Record 19 of Set 6 | sfantu gheorghe
# Processing Record 20 of Set 6 | kisesa
# Processing Record 21 of Set 6 | geraldton
# Processing Record 22 of Set 6 | burgeo
# Processing Record 23 of Set 6 | acuna
# City not found. Skipping...
# Processing Record 24 of Set 6 | tasiilaq
# Processing Record 25 of Set 6 | sola
# Processing Record 26 of Set 6 | matara
# Processing Record 27 of Set 6 | martil
# Processing Record 28 of Set 6 | awjilah
# Processing Record 29 of Set 6 | caldwell
# Processing Record 30 of Set 6 | druzhba
# Processing Record 31 of Set 6 | ulaangom
# Processing Record 32 of Set 6 | kindu
# Processing Record 33 of Set 6 | victoria
# Processing Record 34 of Set 6 | qianan
# Processing Record 35 of Set 6 | geilo
# Processing Record 36 of Set 6 | honiara
# Processing Record 37 of Set 6 | savannakhet
# Processing Record 38 of Set 6 | oksfjord
# Processing Record 39 of Set 6 | rawson
# Processing Record 40 of Set 6 | lar gerd
# City not found. Skipping...
# Processing Record 41 of Set 6 | hilo
# Processing Record 42 of Set 6 | balimo
# City not found. Skipping...
# Processing Record 43 of Set 6 | vila do maio
# Processing Record 44 of Set 6 | umm kaddadah
# Processing Record 45 of Set 6 | naze
# Processing Record 46 of Set 6 | cayenne
# Processing Record 47 of Set 6 | port-gentil
# Processing Record 48 of Set 6 | rafaela
# Processing Record 49 of Set 6 | matay
# Processing Record 50 of Set 6 | peshawar
# Processing Record 1 of Set 7 | kawalu
# Processing Record 2 of Set 7 | weligama
# Processing Record 3 of Set 7 | eydhafushi
# Processing Record 4 of Set 7 | sept-iles
# Processing Record 5 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 7 | itubera
# Processing Record 7 of Set 7 | cidreira
# Processing Record 8 of Set 7 | alta floresta
# Processing Record 9 of Set 7 | tura
# Processing Record 10 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 7 | ancud
# Processing Record 12 of Set 7 | komsomolskiy
# Processing Record 13 of Set 7 | zhezkazgan
# Processing Record 14 of Set 7 | aksarka
# Processing Record 15 of Set 7 | kaitangata
# Processing Record 16 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 7 | wadi musa
# Processing Record 18 of Set 7 | axim
# Processing Record 19 of Set 7 | lebedinyy
# Processing Record 20 of Set 7 | mikhaylovka
# Processing Record 21 of Set 7 | arlit
# Processing Record 22 of Set 7 | buala
# Processing Record 23 of Set 7 | luganville
# Processing Record 24 of Set 7 | leshan
# Processing Record 25 of Set 7 | boddam
# Processing Record 26 of Set 7 | pangoa
# Processing Record 27 of Set 7 | port blair
# Processing Record 28 of Set 7 | chimore
# Processing Record 29 of Set 7 | chifeng
# Processing Record 30 of Set 7 | orange cove
# Processing Record 31 of Set 7 | clyde river
# Processing Record 32 of Set 7 | lompoc
# Processing Record 33 of Set 7 | wanning
# Processing Record 34 of Set 7 | bambous virieux
# Processing Record 35 of Set 7 | nicoya
# Processing Record 36 of Set 7 | tual
# Processing Record 37 of Set 7 | coahuayana
# Processing Record 38 of Set 7 | nuuk
# Processing Record 39 of Set 7 | sorland
# Processing Record 40 of Set 7 | dunedin
# Processing Record 41 of Set 7 | mangaratiba
# Processing Record 42 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 7 | bocaranga
# City not found. Skipping...
# Processing Record 44 of Set 7 | jeremie
# Processing Record 45 of Set 7 | kodinsk
# Processing Record 46 of Set 7 | bilibino
# Processing Record 47 of Set 7 | derzhavinsk
# Processing Record 48 of Set 7 | nikolskoye-na-cheremshane
# City not found. Skipping...
# Processing Record 49 of Set 7 | vendas novas
# Processing Record 50 of Set 7 | ostrovnoy
# Processing Record 1 of Set 8 | nalut
# Processing Record 2 of Set 8 | alice springs
# Processing Record 3 of Set 8 | velikodvorskiy
# Processing Record 4 of Set 8 | avarua
# Processing Record 5 of Set 8 | paciran
# Processing Record 6 of Set 8 | torbay
# Processing Record 7 of Set 8 | fare
# Processing Record 8 of Set 8 | yulara
# Processing Record 9 of Set 8 | salalah
# Processing Record 10 of Set 8 | vila franca do campo
# Processing Record 11 of Set 8 | grootfontein
# Processing Record 12 of Set 8 | ca mau
# Processing Record 13 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 8 | muros
# Processing Record 15 of Set 8 | clinton
# Processing Record 16 of Set 8 | srednekolymsk
# Processing Record 17 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 18 of Set 8 | beringovskiy
# Processing Record 19 of Set 8 | khilok
# Processing Record 20 of Set 8 | saint-augustin
# Processing Record 21 of Set 8 | miranda
# Processing Record 22 of Set 8 | papetoai
# Processing Record 23 of Set 8 | pevek
# Processing Record 24 of Set 8 | machilipatnam
# Processing Record 25 of Set 8 | sisimiut
# Processing Record 26 of Set 8 | narsaq
# Processing Record 27 of Set 8 | fort nelson
# Processing Record 28 of Set 8 | praia
# Processing Record 29 of Set 8 | mongo
# Processing Record 30 of Set 8 | gilgit
# Processing Record 31 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 32 of Set 8 | dauphin
# Processing Record 33 of Set 8 | poya
# Processing Record 34 of Set 8 | kokstad
# Processing Record 35 of Set 8 | zvishavane
# Processing Record 36 of Set 8 | nantucket
# Processing Record 37 of Set 8 | beian
# Processing Record 38 of Set 8 | henties bay
# Processing Record 39 of Set 8 | gisborne
# Processing Record 40 of Set 8 | maputo
# Processing Record 41 of Set 8 | sakakah
# Processing Record 42 of Set 8 | elliot lake
# Processing Record 43 of Set 8 | rocha
# Processing Record 44 of Set 8 | vila velha
# Processing Record 45 of Set 8 | dubbo
# Processing Record 46 of Set 8 | trabzon
# Processing Record 47 of Set 8 | kavieng
# Processing Record 48 of Set 8 | bakchar
# Processing Record 49 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 8 | kirakira
# Processing Record 1 of Set 9 | krasnyy luch
# Processing Record 2 of Set 9 | huilong
# Processing Record 3 of Set 9 | san pedro
# Processing Record 4 of Set 9 | volovo
# Processing Record 5 of Set 9 | sao filipe
# Processing Record 6 of Set 9 | moron
# Processing Record 7 of Set 9 | mackay
# Processing Record 8 of Set 9 | asau
# Processing Record 9 of Set 9 | koulikoro
# Processing Record 10 of Set 9 | falmouth
# Processing Record 11 of Set 9 | nara
# Processing Record 12 of Set 9 | ochakiv
# Processing Record 13 of Set 9 | novopavlovka
# Processing Record 14 of Set 9 | saskylakh
# Processing Record 15 of Set 9 | mumbwa
# Processing Record 16 of Set 9 | kasulu
# Processing Record 17 of Set 9 | manokwari
# Processing Record 18 of Set 9 | osa
# Processing Record 19 of Set 9 | skibbereen
# Processing Record 20 of Set 9 | montepuez
# Processing Record 21 of Set 9 | petatlan
# Processing Record 22 of Set 9 | sitka
# Processing Record 23 of Set 9 | mentougou
# Processing Record 24 of Set 9 | meridian
# Processing Record 25 of Set 9 | gawler
# Processing Record 26 of Set 9 | shingu
# Processing Record 27 of Set 9 | belle fourche
# Processing Record 28 of Set 9 | bonavista
# Processing Record 29 of Set 9 | mozelos
# Processing Record 30 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 31 of Set 9 | esperance
# Processing Record 32 of Set 9 | irsha
# Processing Record 33 of Set 9 | rorvik
# Processing Record 34 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 35 of Set 9 | aden
# Processing Record 36 of Set 9 | la palma
# Processing Record 37 of Set 9 | shakiso
# Processing Record 38 of Set 9 | mantua
# Processing Record 39 of Set 9 | airai
# Processing Record 40 of Set 9 | iguape
# Processing Record 41 of Set 9 | yarada
# Processing Record 42 of Set 9 | kollam
# Processing Record 43 of Set 9 | guerrero negro
# Processing Record 44 of Set 9 | yar-sale
# Processing Record 45 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 9 | cedeno
# Processing Record 47 of Set 9 | yerbogachen
# Processing Record 48 of Set 9 | aldan
# Processing Record 49 of Set 9 | saint anthony
# Processing Record 50 of Set 9 | pyu
# Processing Record 1 of Set 10 | olafsvik
# Processing Record 2 of Set 10 | metehara
# City not found. Skipping...
# Processing Record 3 of Set 10 | bilma
# Processing Record 4 of Set 10 | luderitz
# Processing Record 5 of Set 10 | sao joao da barra
# Processing Record 6 of Set 10 | quelimane
# Processing Record 7 of Set 10 | nenjiang
# Processing Record 8 of Set 10 | chumikan
# Processing Record 9 of Set 10 | santo antonio do ica
# Processing Record 10 of Set 10 | isangel
# Processing Record 11 of Set 10 | mitu
# Processing Record 12 of Set 10 | safaqis
# City not found. Skipping...
# Processing Record 13 of Set 10 | birjand
# Processing Record 14 of Set 10 | port elizabeth
# Processing Record 15 of Set 10 | hofn
# Processing Record 16 of Set 10 | aswan
# Processing Record 17 of Set 10 | lakes entrance
# Processing Record 18 of Set 10 | totoral
# Processing Record 19 of Set 10 | santa fe
# Processing Record 20 of Set 10 | waitati
# Processing Record 21 of Set 10 | mabaruma
# Processing Record 22 of Set 10 | alugan
# Processing Record 23 of Set 10 | banes
# Processing Record 24 of Set 10 | santa cruz
# Processing Record 25 of Set 10 | seminole
# Processing Record 26 of Set 10 | sayalgudi
# City not found. Skipping...
# Processing Record 27 of Set 10 | los llanos de aridane
# Processing Record 28 of Set 10 | malartic
# Processing Record 29 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 10 | campos do jordao
# Processing Record 31 of Set 10 | isla vista
# Processing Record 32 of Set 10 | tommot
# Processing Record 33 of Set 10 | bac lieu
# Processing Record 34 of Set 10 | porbandar
# Processing Record 35 of Set 10 | den helder
# Processing Record 36 of Set 10 | santo tomas
# Processing Record 37 of Set 10 | aykhal
# Processing Record 38 of Set 10 | norsup
# Processing Record 39 of Set 10 | harmanli
# Processing Record 40 of Set 10 | newport
# Processing Record 41 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 42 of Set 10 | biltine
# Processing Record 43 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 44 of Set 10 | susangerd
# Processing Record 45 of Set 10 | kushiro
# Processing Record 46 of Set 10 | turkmenabat
# Processing Record 47 of Set 10 | zhangjiakou
# Processing Record 48 of Set 10 | denpasar
# Processing Record 49 of Set 10 | hokitika
# Processing Record 50 of Set 10 | formosa
# Processing Record 1 of Set 11 | ko samui
# Processing Record 2 of Set 11 | matagami
# Processing Record 3 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 4 of Set 11 | marsa matruh
# Processing Record 5 of Set 11 | itapuranga
# Processing Record 6 of Set 11 | ahipara
# Processing Record 7 of Set 11 | nalagarh
# Processing Record 8 of Set 11 | emba
# Processing Record 9 of Set 11 | areosa
# Processing Record 10 of Set 11 | zeya
# Processing Record 11 of Set 11 | lata
# Processing Record 12 of Set 11 | tuatapere
# Processing Record 13 of Set 11 | kuruman
# Processing Record 14 of Set 11 | nisia floresta
# Processing Record 15 of Set 11 | hami
# Processing Record 16 of Set 11 | hasaki
# Processing Record 17 of Set 11 | changping
# Processing Record 18 of Set 11 | oum hadjer
# Processing Record 19 of Set 11 | wau
# Processing Record 20 of Set 11 | hun
# Processing Record 21 of Set 11 | lagos
# Processing Record 22 of Set 11 | nabire
# Processing Record 23 of Set 11 | la ronge
# Processing Record 24 of Set 11 | greytown
# Processing Record 25 of Set 11 | mehamn
# Processing Record 26 of Set 11 | bud
# Processing Record 27 of Set 11 | mujiayingzi
# Processing Record 28 of Set 11 | chornukhy
# Processing Record 29 of Set 11 | storm lake
# Processing Record 30 of Set 11 | ukiah
# Processing Record 31 of Set 11 | amahai
# Processing Record 32 of Set 11 | qafsah
# City not found. Skipping...
# Processing Record 33 of Set 11 | khasan
# Processing Record 34 of Set 11 | fredericksburg
# Processing Record 35 of Set 11 | besikduzu
# Processing Record 36 of Set 11 | kem
# Processing Record 37 of Set 11 | prince rupert
# Processing Record 38 of Set 11 | craig
# Processing Record 39 of Set 11 | najran
# Processing Record 40 of Set 11 | sao jose da coroa grande
# Processing Record 41 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 11 | pangnirtung
# Processing Record 43 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 11 | mananjary
# Processing Record 45 of Set 11 | chokwe
# Processing Record 46 of Set 11 | lyuban
# Processing Record 47 of Set 11 | sheridan
# Processing Record 48 of Set 11 | turayf
# Processing Record 49 of Set 11 | abu kamal
# Processing Record 50 of Set 11 | mogadishu
# Processing Record 1 of Set 12 | taree
# Processing Record 2 of Set 12 | margate
# Processing Record 3 of Set 12 | flinders
# Processing Record 4 of Set 12 | wawa
# Processing Record 5 of Set 12 | reconquista
# Processing Record 6 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 7 of Set 12 | hvide sande
# Processing Record 8 of Set 12 | finnsnes
# Processing Record 9 of Set 12 | portland
# Processing Record 10 of Set 12 | road town
# Processing Record 11 of Set 12 | zhumadian
# Processing Record 12 of Set 12 | yeppoon
# Processing Record 13 of Set 12 | ornskoldsvik
# Processing Record 14 of Set 12 | mwene-ditu
# Processing Record 15 of Set 12 | laguna
# Processing Record 16 of Set 12 | havre-saint-pierre
# Processing Record 17 of Set 12 | te anau
# Processing Record 18 of Set 12 | loei
# Processing Record 19 of Set 12 | saint-pierre
# Processing Record 20 of Set 12 | dubti
# Processing Record 21 of Set 12 | taoudenni
# Processing Record 22 of Set 12 | sirsi
# Processing Record 23 of Set 12 | yerofey pavlovich
# Processing Record 24 of Set 12 | catia la mar
# Processing Record 25 of Set 12 | mitsamiouli
# Processing Record 26 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 12 | kisanga
# Processing Record 28 of Set 12 | xining
# Processing Record 29 of Set 12 | masingbi
# Processing Record 30 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 12 | shimoda
# Processing Record 32 of Set 12 | nyurba
# Processing Record 33 of Set 12 | coolum beach
# Processing Record 34 of Set 12 | codrington
# Processing Record 35 of Set 12 | aranos
# Processing Record 36 of Set 12 | sioux lookout
# Processing Record 37 of Set 12 | batticaloa
# Processing Record 38 of Set 12 | port macquarie
# Processing Record 39 of Set 12 | vostok
# Processing Record 40 of Set 12 | slonim
# Processing Record 41 of Set 12 | port keats
# Processing Record 42 of Set 12 | dingle
# Processing Record 43 of Set 12 | lavumisa
# Processing Record 44 of Set 12 | brawley
# Processing Record 45 of Set 12 | tado
# Processing Record 46 of Set 12 | antofagasta
# Processing Record 47 of Set 12 | pacasmayo
# Processing Record 48 of Set 12 | clonakilty
# Processing Record 49 of Set 12 | surt
# Processing Record 50 of Set 12 | adrar
# Processing Record 1 of Set 13 | koslan
# Processing Record 2 of Set 13 | sur
# Processing Record 3 of Set 13 | kantunilkin
# Processing Record 4 of Set 13 | merauke
# Processing Record 5 of Set 13 | kedrovyy
# Processing Record 6 of Set 13 | karpathos
# Processing Record 7 of Set 13 | aksu
# Processing Record 8 of Set 13 | kungurtug
# Processing Record 9 of Set 13 | rivadavia
# Processing Record 10 of Set 13 | godda
# Processing Record 11 of Set 13 | sao gabriel da cachoeira
# Processing Record 12 of Set 13 | rockland
# Processing Record 13 of Set 13 | gat
# Processing Record 14 of Set 13 | kerouane
# Processing Record 15 of Set 13 | maracas
# Processing Record 16 of Set 13 | kuala terengganu
# Processing Record 17 of Set 13 | ciudad bolivar
# Processing Record 18 of Set 13 | novoshakhtinsk
# Processing Record 19 of Set 13 | mogochin
# City not found. Skipping...
# Processing Record 20 of Set 13 | rapid valley
# Processing Record 21 of Set 13 | yarensk
# Processing Record 22 of Set 13 | kennett
# Processing Record 23 of Set 13 | nizwa
# Processing Record 24 of Set 13 | los palacios
# Processing Record 25 of Set 13 | saurimo
# Processing Record 26 of Set 13 | tautira
# Processing Record 27 of Set 13 | ibra
# Processing Record 28 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 29 of Set 13 | huarmey
# Processing Record 30 of Set 13 | ribas do rio pardo
# Processing Record 31 of Set 13 | yenangyaung
# Processing Record 32 of Set 13 | tomakomai
# Processing Record 33 of Set 13 | kanniyakumari
# Processing Record 34 of Set 13 | manati
# Processing Record 35 of Set 13 | bonfim
# Processing Record 36 of Set 13 | luwuk
# Processing Record 37 of Set 13 | polovinnoye
# Processing Record 38 of Set 13 | seymchan
# Processing Record 39 of Set 13 | gossaigaon
# Processing Record 40 of Set 13 | lubbock
# Processing Record 41 of Set 13 | sainte-maxime
# Processing Record 42 of Set 13 | chippewa falls
# Processing Record 43 of Set 13 | beira
# Processing Record 44 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 45 of Set 13 | praya
# Processing Record 46 of Set 13 | jinchang
# Processing Record 47 of Set 13 | samarai
# Processing Record 48 of Set 13 | meadow lake
# Processing Record 49 of Set 13 | manga
# Processing Record 50 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 14 | ambulu
# Processing Record 2 of Set 14 | colchester
# Processing Record 3 of Set 14 | mercaderes
# Processing Record 4 of Set 14 | lamu
# Processing Record 5 of Set 14 | ayna
# Processing Record 6 of Set 14 | chicama
# Processing Record 7 of Set 14 | khani
# Processing Record 8 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 9 of Set 14 | san juan de los morros
# Processing Record 10 of Set 14 | riviere-au-renard
# Processing Record 11 of Set 14 | cap malheureux
# Processing Record 12 of Set 14 | mondragone
# Processing Record 13 of Set 14 | charcas
# Processing Record 14 of Set 14 | daru
# Processing Record 15 of Set 14 | kovdor
# Processing Record 16 of Set 14 | conde
# Processing Record 17 of Set 14 | eureka
# Processing Record 18 of Set 14 | carlisle
# Processing Record 19 of Set 14 | mudyuga
# City not found. Skipping...
# Processing Record 20 of Set 14 | jiblah
# Processing Record 21 of Set 14 | tongliao
# Processing Record 22 of Set 14 | kerki
# City not found. Skipping...
# Processing Record 23 of Set 14 | le havre
# Processing Record 24 of Set 14 | delijan
# Processing Record 25 of Set 14 | casma
# Processing Record 26 of Set 14 | roma
# Processing Record 27 of Set 14 | egvekinot
# Processing Record 28 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 14 | yelizovo
# Processing Record 30 of Set 14 | nelson bay
# Processing Record 31 of Set 14 | north bend
# Processing Record 32 of Set 14 | marawi
# Processing Record 33 of Set 14 | russkaya polyana
# Processing Record 34 of Set 14 | taltal
# Processing Record 35 of Set 14 | manicore
# Processing Record 36 of Set 14 | elizabeth city
# Processing Record 37 of Set 14 | kwekwe
# Processing Record 38 of Set 14 | hue
# Processing Record 39 of Set 14 | zilupe
# Processing Record 40 of Set 14 | husavik
# Processing Record 41 of Set 14 | paita
# Processing Record 42 of Set 14 | miragoane
# Processing Record 43 of Set 14 | namatanai
# Processing Record 44 of Set 14 | khor
# Processing Record 45 of Set 14 | birao
# Processing Record 46 of Set 14 | nanakuli
# Processing Record 47 of Set 14 | de land
# Processing Record 48 of Set 14 | swinoujscie
# Processing Record 49 of Set 14 | zyryanskoye
# Processing Record 50 of Set 14 | olinda
# Processing Record 1 of Set 15 | redmond
# Processing Record 2 of Set 15 | ranghulu
# Processing Record 3 of Set 15 | otjiwarongo
# Processing Record 4 of Set 15 | puerto madryn
# Processing Record 5 of Set 15 | kupang
# Processing Record 6 of Set 15 | corinto
# Processing Record 7 of Set 15 | verkhnevilyuysk
# Processing Record 8 of Set 15 | santa rosa
# Processing Record 9 of Set 15 | guozhen
# Processing Record 10 of Set 15 | barra patuca
# Processing Record 11 of Set 15 | cuamba
# Processing Record 12 of Set 15 | souris
# Processing Record 13 of Set 15 | abha
# Processing Record 14 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 16 of Set 15 | tondano
# Processing Record 17 of Set 15 | tilichiki
# Processing Record 18 of Set 15 | general jose eduvigis diaz
# Processing Record 19 of Set 15 | northam
# Processing Record 20 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 21 of Set 15 | ondangwa
# Processing Record 22 of Set 15 | hadsten
# Processing Record 23 of Set 15 | port hueneme
# Processing Record 24 of Set 15 | oksbol
# Processing Record 25 of Set 15 | rzhaksa
# Processing Record 26 of Set 15 | greenfield
# Processing Record 27 of Set 15 | mecca
# Processing Record 28 of Set 15 | belyy yar
# Processing Record 29 of Set 15 | valdivia
# Processing Record 30 of Set 15 | huicungo
# Processing Record 31 of Set 15 | port hardy
# Processing Record 32 of Set 15 | karatau
# Processing Record 33 of Set 15 | cleethorpes
# Processing Record 34 of Set 15 | oistins
# Processing Record 35 of Set 15 | sturgeon falls
# Processing Record 36 of Set 15 | bandar
# Processing Record 37 of Set 15 | salinopolis
# Processing Record 38 of Set 15 | abu dhabi
# Processing Record 39 of Set 15 | rosita
# Processing Record 40 of Set 15 | touros
# Processing Record 41 of Set 15 | manbij
# Processing Record 42 of Set 15 | loukhi
# Processing Record 43 of Set 15 | barcelos
# Processing Record 44 of Set 15 | normandin
# Processing Record 45 of Set 15 | xai-xai
# Processing Record 46 of Set 15 | grindavik
# Processing Record 47 of Set 15 | kovur
# Processing Record 48 of Set 15 | walvis bay
# Processing Record 49 of Set 15 | loding
# Processing Record 50 of Set 15 | katima mulilo
# Processing Record 1 of Set 16 | fukuma
# Processing Record 2 of Set 16 | coos bay
# Processing Record 3 of Set 16 | koutsouras
# Processing Record 4 of Set 16 | naifaru
# Processing Record 5 of Set 16 | bacolod
# Processing Record 6 of Set 16 | kananga
# Processing Record 7 of Set 16 | kalmunai
# Processing Record 8 of Set 16 | san policarpo
# Processing Record 9 of Set 16 | khalkhal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Mago  53.2514  140.1822     37.90        96         100
# 1       Mataura -46.1927  168.8643     39.60        95          52
# 2      Lorengau  -2.0226  147.2712     80.29        80          74
# 3  Norman Wells  65.2820 -126.8329     46.44        76          75
# 4         Bonga   7.2833   36.2333     61.21        97          54
# 5       Rikitea -23.1203 -134.9692     75.58        80         100
# 6  Punta Arenas -53.1500  -70.9167     39.31        87          20
# 7        Castro -24.7911  -50.0119     73.47        49           1
# 8       Uruzgan  32.8333   66.0000     82.13         5           0
# 9   Port Alfred -33.5906   26.8910     61.59        83           0
#
#    Wind Speed Country Current Description
# 0        7.23      RU     overcast clouds
# 1        0.51      NZ       broken clouds
# 2        4.07      PG       broken clouds
# 3       12.66      CA          light rain
# 4        1.14      ET       broken clouds
# 5       10.25      PF     overcast clouds
# 6        7.56      CL          few clouds
# 7        8.43      BR           clear sky
# 8        4.83      AF           clear sky
# 9       14.29      ZA           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Mago      RU  53.2514  140.1822     37.90        96         100
# 1       Mataura      NZ -46.1927  168.8643     39.60        95          52
# 2      Lorengau      PG  -2.0226  147.2712     80.29        80          74
# 3  Norman Wells      CA  65.2820 -126.8329     46.44        76          75
# 4         Bonga      ET   7.2833   36.2333     61.21        97          54
# 5       Rikitea      PF -23.1203 -134.9692     75.58        80         100
# 6  Punta Arenas      CL -53.1500  -70.9167     39.31        87          20
# 7        Castro      BR -24.7911  -50.0119     73.47        49           1
# 8       Uruzgan      AF  32.8333   66.0000     82.13         5           0
# 9   Port Alfred      ZA -33.5906   26.8910     61.59        83           0
#
#    Wind Speed Current Description
# 0        7.23     overcast clouds
# 1        0.51       broken clouds
# 2        4.07       broken clouds
# 3       12.66          light rain
# 4        1.14       broken clouds
# 5       10.25     overcast clouds
# 6        7.56          few clouds
# 7        8.43           clear sky
# 8        4.83           clear sky
# 9       14.29           clear sky

# %%
# Create the output file (CSV).
output_data_file = "./Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
